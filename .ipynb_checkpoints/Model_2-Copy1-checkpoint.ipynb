# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
import seaborn as sns
import datetime
from datetime import datetime
import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs
df = pd.read_csv("rts.csv",index_col = "RTSI$ Index",parse_dates=["RTSI$ Index"])

# %%
df = df.drop("Dates")
df = df.drop("Unnamed: 6",axis = 1)
df = df.rename_axis("Date")
df.head()
# Out:
#            Last Price High Price Low Price     Volume Open Price   SPX Index  \
# Date
# 10.01.2006    1190.34     1192.9    1128.2   45551788     1128.2  03.01.2006
# 11.01.2006    1216.66    1216.92   1188.86   98596352    1190.04  04.01.2006
# 12.01.2006    1255.92    1261.42   1216.96  127009136    1216.96  05.01.2006
# 13.01.2006    1239.76    1261.57    1234.1   72828544    1255.65  06.01.2006
# 16.01.2006     1276.9    1277.26   1240.05   57721104    1240.05  09.01.2006
#
#            Last Price.1 High Price.1 Low Price.1    Volume.1 Open Price.1
# Date
# 10.01.2006       1268.8      1270.22     1245.74  1511666432      1248.29
# 11.01.2006      1273.46      1275.37     1267.74  1451294208       1268.8
# 12.01.2006      1273.48      1276.91      1270.3  1419537536      1273.46
# 13.01.2006      1285.45      1286.09     1273.48  1536703616      1273.48
# 16.01.2006      1290.15      1290.78     1284.82  1317811584      1285.45

# %%
df.columns
# Out:
# Index(['Last Price', 'High Price', 'Low Price', 'Volume', 'Open Price',
#        'SPX Index', 'Last Price.1', 'High Price.1', 'Low Price.1', 'Volume.1',
#        'Open Price.1', 'Date'],
#       dtype='object')

# %%
df["Date"] = df.index

# %%
df.dropna(inplace = True)

# %%
df[df.columns[:5]] = df[df.columns[:5]].astype("float")
df[df.columns[6:-1]] = df[df.columns[6:-1]].astype("float")

# %%
def todate(x):
    return datetime.strptime(x,'%d.%m.%Y')
df.index = df.index.map(todate)
df["SPX Index"] = df["SPX Index"].apply(todate)

# %%
df.index
# Out:
# DatetimeIndex(['2006-01-10', '2006-01-11', '2006-01-12', '2006-01-13',
#                '2006-01-16', '2006-01-17', '2006-01-18', '2006-01-19',
#                '2006-01-20', '2006-01-23',
#                ...
#                '2018-02-19', '2018-02-20', '2018-02-21', '2018-02-22',
#                '2018-02-26', '2018-02-27', '2018-02-28', '2018-03-01',
#                '2018-03-02', '2018-03-05'],
#               dtype='datetime64[ns]', name='Date', length=3036, freq=None)

# %%
def plotMovingAverage(data, n):
    rolling_mean = data.rolling(window=n).mean()

    plt.figure(figsize=(15,5))
    plt.title("Moving average\n window size = {}".format(n))
    plt.plot(rolling_mean,data.Date ,"g", label="Rolling mean trend")
    plt.plot(data[n:], label="Actual values")
    plt.legend(loc="upper left")
    plt.grid(True)
    plt.xlabel(df.index.name)
    plt.ylabel("Last Price of RTS")
    
    
def tsplot(y, lags=None, figsize=(12, 7), style='bmh'):
    
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
    with plt.style.context(style):    
        fig = plt.figure(figsize=figsize)
        layout = (2, 2)
        acf_ax = plt.subplot2grid(layout, (1, 0))
        pacf_ax = plt.subplot2grid(layout, (1, 1))
        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax, alpha=0.5)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax, alpha=0.5)
        plt.tight_layout()
    return

# %%
df.columns
# Out:
# Index(['Last Price', 'High Price', 'Low Price', 'Volume', 'Open Price',
#        'SPX Index', 'Last Price.1', 'High Price.1', 'Low Price.1', 'Volume.1',
#        'Open Price.1'],
#       dtype='object')

# %%
plt.plot(df.index,df["Last Price"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-1b245a07311c> in <module>()
# ----> 1 plt.plot(df.index,df["Last Price"])
#
# //anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3159         ax.hold(hold)
#    3160     try:
# -> 3161         ret = ax.plot(*args, **kwargs)
#    3162     finally:
#    3163         ax.hold(washold)
#
# //anaconda/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1817                     warnings.warn(msg % (label_namer, func.__name__),
#    1818                                   RuntimeWarning, stacklevel=2)
# -> 1819             return func(ax, *args, **kwargs)
#    1820         pre_doc = inner.__doc__
#    1821         if pre_doc is None:
#
# //anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1381
#    1382         for line in self._get_lines(*args, **kwargs):
# -> 1383             self.add_line(line)
#    1384             lines.append(line)
#    1385
#
# //anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in add_line(self, line)
#    1701             line.set_clip_path(self.patch)
#    1702
# -> 1703         self._update_line_limits(line)
#    1704         if not line.get_label():
#    1705             line.set_label('_line%d' % len(self.lines))
#
# //anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    1723         Figures out the data limit of the given line, updating self.dataLim.
#    1724         """
# -> 1725         path = line.get_path()
#    1726         if path.vertices.size == 0:
#    1727             return
#
# //anaconda/lib/python3.5/site-packages/matplotlib/lines.py in get_path(self)
#     936         """
#     937         if self._invalidy or self._invalidx:
# --> 938             self.recache()
#     939         return self._path
#     940
#
# //anaconda/lib/python3.5/site-packages/matplotlib/lines.py in recache(self, always)
#     623                 x = ma.asarray(xconv, np.float_).filled(np.nan)
#     624             else:
# --> 625                 x = np.asarray(xconv, np.float_)
#     626             x = x.ravel()
#     627         else:
#
# //anaconda/lib/python3.5/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     480
#     481     """
# --> 482     return array(a, dtype, copy=False, order=order)
#     483
#     484 def asanyarray(a, dtype=None, order=None):
#
# ValueError: could not convert string to float: '05.03.2018'

# %%
fig, ax = plt.subplots()
ax.plot(df.index, df["Last Price"])
#plt.plot(df.index,df["Last Price"])
ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')

# %%
df.index[0]
# Out:
# Timestamp('2006-01-10 00:00:00')

# %%
plotMovingAverage(df["Last Price"],n = 50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-da92e935a9e8> in <module>()
# ----> 1 plotMovingAverage(df["Last Price"],n = 50)
#
# <ipython-input-9-70fd22615f33> in plotMovingAverage(data, n)
#       4     plt.figure(figsize=(15,5))
#       5     plt.title("Moving average\n window size = {}".format(n))
# ----> 6     plt.plot(rolling_mean,data.Date ,"g", label="Rolling mean trend")
#       7     plt.plot(data[n:], label="Actual values")
#       8     plt.legend(loc="upper left")
#
# //anaconda/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'Date'

# %%
print("Критерий Дики-Фуллера")#проверка на стационарность
result = sm.tsa.stattools.adfuller(df["Last Price"])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# Критерий Дики-Фуллера
# ADF Statistic: -1.961476
# p-value: 0.303716
# Critical Values:
# 	10%: -2.567
# 	5%: -2.862
# 	1%: -3.433

# %%
tsplot(df["Last Price"],lags = 50)

# %%
plt.hist(df["Last Price"].pct_change()[1:],bins=50)
plt.title("Daily Returns of RTS")
plt.show()

# %%
plt.hist(df["Last Price.1"].pct_change()[1:],bins=50)
plt.title("Daily returns of S&P")
plt.show()

# %% [markdown]
# ### Tрендоследящая стратегия

# %% [markdown]
# Построим график средних значений для разных окон

# %%
#для ртс
df["Last_price_rolling_30"] = df["Last Price"].rolling(window=30).mean()
df["Last_price_rolling_150"] = df["Last Price"].rolling(window=150).mean()
df[['Last Price', 'Last_price_rolling_30', 'Last_price_rolling_150']].plot(figsize = (10,5))
plt.show()

# %%
#для S&P
df["Last_price_rolling_30_sp"] = df["Last Price.1"].rolling(window=30).mean()

df["Last_price_rolling_150_sp"] = df["Last Price.1"].rolling(window=150).mean()

df[['Last Price.1', 'Last_price_rolling_30_sp', 'Last_price_rolling_150_sp']].plot(figsize = (10,5))
plt.show()

# %% [markdown]
# Элементарная стратегия

# %%
def strategy(short, long, a):
    #находим точки когда покупаем и продаем
    signs = pd.DataFrame(index=a.index)
    signs['signal'] = 0.0
    signs['short_mavg_rts'] = a.rolling(window=short, min_periods=1).mean()
    signs['long_mavg_rts'] = a.rolling(window=long, min_periods=1, center=False).mean()
    signs["signal"] = np.where(signs["short_mavg_rts"] - signs["long_mavg_rts"] >0, 1,0)#получаем тренд
    signs["trades"] = signs["signal"].diff()
    fig = plt.figure()
    ax1 = fig.add_subplot(212,ylabel='Price in $')
    ax1.plot(a, color='g')
    ax1.plot(signs["short_mavg_rts"])
    ax1.plot(signs["long_mavg_rts"])
    signs[['short_mavg_rts', 'long_mavg_rts']].plot(ax=ax1,figsize = (11,7))
    ax1.plot(signs.loc[signs.trades == 1.0].index, signs.short_mavg_rts[signs.trades == 1.0],'*', markersize=10,
             color='y')
    ax1.plot(signs.loc[signs.trades == -1.0].index, signs.short_mavg_rts[signs.trades == -1.0],'^', markersize=10,
             color='black')    
    plt.show()
    
    print("Было сделано %s сделок покупки и продажи"%signs.trades.value_counts()[1])
    #находим стоимость портфеля за рассматриваемый период
    money = 100000
    trades = pd.DataFrame(index=signs.index).fillna(0.0)
    trades['RTS'] = 100*signs['signal']#покупаем 100 штук в каждой сделке, можем занимать деньги, соответственно обратно тоже продаем 100 штук
    port = trades.multiply(a,axis = 0)
    pos_diff = trades.diff()
    port['holdings'] = (trades.multiply(a,axis = 0)).sum(axis=1)
    port['cash'] = money - (pos_diff.multiply(a,axis =0)).sum(axis=1).cumsum()   
    port['total'] = port['cash'] + port['holdings']
    fig2 = plt.figure()#стоимость портфеля
    ax2 = fig2.add_subplot(212, ylabel='Portfolio value in $')
    port['total'].plot(ax=ax2, figsize = (10,5))
    plt.show()

# %%
strategy(30,100,df["Last Price"])
# Out:
# Было сделано 16 сделок покупки и продажи

# %%
strategy(3,100,df["Last Price"])
# Out:
# Было сделано 33 сделок покупки и продажи

# %%
strategy(50,100,df["Last Price"])
# Out:
# Было сделано 15 сделок покупки и продажи

# %%
strategy(1,10,df["Last Price"])
# Out:
# Было сделано 232 сделок покупки и продажи
